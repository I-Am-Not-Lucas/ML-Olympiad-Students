# %% [markdown]
# <h3> Importação inical das bibliotecas

# %%
import pandas as pd
import numpy as np

# %%
df_test = pd.read_csv("/content/test.csv")
df_train = pd.read_csv("/content/train.csv")

# %%
print(df_train.shape,df_test.shape)
# Out:
# (17836, 12) (7644, 11)

# %%
df_test["status_do_caso"] = 0

# %%
df_train["status_do_caso"].head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: status_do_caso, dtype: int64

# %%
df_test
# Out:
#      id_do_caso        continente educacao_do_empregado  \
# 0     EZYV22339              Ásia       Ensino Superior
# 1      EZYV9333              Ásia              Mestrado
# 2      EZYV9740              Ásia       Ensino Superior
# 3      EZYV3328              Ásia       Ensino Superior
# 4     EZYV12321    América do Sul       Ensino Superior
# ...         ...               ...                   ...
# 7639  EZYV19907  América do Norte       Ensino Superior
# 7640    EZYV576              Ásia          Ensino Médio
# 7641   EZYV1804              Ásia              Mestrado
# 7642  EZYV13543  América do Norte              Mestrado
# 7643  EZYV17903              Ásia       Ensino Superior
#
#      tem_experiencia_de_trabalho requer_treinamento_de_trabalho  \
# 0                              S                              N
# 1                              N                              S
# 2                              S                              N
# ...

# %%
df_test2 = df_test[["id_do_caso", "status_do_caso"]]
df_test2
# Out:
#      id_do_caso  status_do_caso
# 0     EZYV22339               0
# 1      EZYV9333               0
# 2      EZYV9740               0
# 3      EZYV3328               0
# 4     EZYV12321               0
# ...         ...             ...
# 7639  EZYV19907               0
# 7640    EZYV576               0
# 7641   EZYV1804               0
# 7642  EZYV13543               0
# 7643  EZYV17903               0
#
# [7644 rows x 2 columns]

# %%
df_test2.to_csv("submissao_dummie2.csv", index=False)
df_test.to_csv
# Out:
# <bound method NDFrame.to_csv of      id_do_caso        continente educacao_do_empregado  \
# 0     EZYV22339              Ásia       Ensino Superior
# 1      EZYV9333              Ásia              Mestrado
# 2      EZYV9740              Ásia       Ensino Superior
# 3      EZYV3328              Ásia       Ensino Superior
# 4     EZYV12321    América do Sul       Ensino Superior
# ...         ...               ...                   ...
# 7639  EZYV19907  América do Norte       Ensino Superior
# 7640    EZYV576              Ásia          Ensino Médio
# 7641   EZYV1804              Ásia              Mestrado
# 7642  EZYV13543  América do Norte              Mestrado
# 7643  EZYV17903              Ásia       Ensino Superior
#
#      tem_experiencia_de_trabalho requer_treinamento_de_trabalho  \
# 0                              S                              N
# 1                              N                              S
# 2                              S                              N
# ...
